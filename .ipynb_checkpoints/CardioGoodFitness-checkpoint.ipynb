# %% [markdown]
# ## Load required libraries

# %%
# import packaged: numpy, pandas, plotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# To enable plotting graphs in Jupyter notebook
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Disable warnings

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load and view few rows of the dataset

# %%
# import csv formatted dataframe and show structure
dataset = pd.read_csv("CardioGoodFitness.csv")
dataset.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# **Observation**
#
# * Product, Gender and MaritalStatus are all categorical variables
# * Age contains the age in years of the customers
# * Education contains, in years, education of the customers
# * All other variables are numerical

# %% [markdown]
# ## What is my dataframe shape?

# %%
dataset.shape
# Out:
# (180, 9)

# %% [markdown]
# * My dataset has 180 rows (records) and 9 columns (variables)

# %% [markdown]
# ## What is my dataframe info?

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# **Observation**
#
# * All variables have the same number of values of 180, meaning I do not have missing values
# * Product, Gender and MaritalStatus are read as objects but should be Categorical variables

# %% [markdown]
# # START - Data Processing

# %% [markdown]
# ### Fixing datatypes

# %%
# first, copy my dataset to a new variable to avoid accidental modification
data = dataset.copy()

# %%
# Convert Product, Gender and MaritalStatus to categorical type
data['Product'] = data.Product.astype('category')
data['Gender'] = data.Gender.astype('category')
data['MaritalStatus'] = data.MaritalStatus.astype('category')

# %%
# Review my dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(3), int64(6)
# memory usage: 9.4 KB

# %%
data.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# **Observation**
#
# * Ofcourse we have the same number of rows accross all variables
# * Product has 3 unique values, while Gender and MaritalStatus have 2 each.
# * TM195 is the most popular product
# * There are more male customers than female
# * The average age of the customers is 28

# %% [markdown]
# ## START - EDA

# %% [markdown]
# ## Explore the numerical variables

# %%
# User defined function to generate boxplot and histogram of my variables.
# This is essential so that I do not have to repeat
# the same block of codes for each variable

def histogram_boxplot(feature, figsize=(15,10), bins = None):
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grid= 2
                                           sharex = True, # x-axis will be shared among all subplots
                                           gridspec_kw = {"height_ratios": (.25, .75)}, 
                                           figsize = figsize 
                                           ) # creating the 2 subplots
    
    # boxplot will be created and a star will indicate the mean value of the column
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='purple')
    
    # For histogram
    sns.distplot(feature, kde=F, ax=ax_hist2, bins=bins) if bins else sns.distplot(feature, kde=False, ax=ax_hist2) 
    ax_hist2.axvline(np.mean(feature), color='g', linestyle='--') # Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %% [markdown]
# ### Observations on Age

# %%
histogram_boxplot(data.Age)

# %% [markdown]
# **Observation**
#
# * The distribution of Age is slightly right skewed
# * Majority of the customers are between the ages of ~20 to ~35
# * Median age is 26 while mean in ~28
# * There are 3 outliers to the right in this variable.
# * While the minimum age is 18 the maximum age sits at 50 years

# %% [markdown]
# ### Observations on Education

# %%
histogram_boxplot(data.Education)

# %% [markdown]
# **Observations**
#
# * Both mean and median are quite close at ~15.6 and 16 respectively
# * There are 2 outliers to the right of the distribution

# %% [markdown]
# ### Observations on Usage

# %%
histogram_boxplot(data.Usage)

# %% [markdown]
# **Observation**
#
# * The distribution of Usage is right skewed
# * Median usage = 3 but the mean is ~3.5
# * It is obvious that we have 2 outliers to the right of the distribution

# %% [markdown]
# ### Observations on Fitness

# %%
histogram_boxplot(data.Fitness)

# %% [markdown]
# **Observation**
#
# * Majority of the Fitness levels are around 3
# * Median Fitness = 3 and mean approximately at 3.3
# * There is an outlier to the left in this variable.
# * While most Fitness levels are around 3, we have observations as low as 1 and as high as 5

# %% [markdown]
# ### Observations on Income

# %%
histogram_boxplot(data.Income)

# %% [markdown]
# **Observations**
#
# * The distribution of Income is positively skewed
# * Most of the customers have incomes around the region of 50,000
# * Unlike the other variables we have studied so far, Income has quite a number of outliers to the right
# * While most Income are at lower end, we have observations where Incomes is above 100,000
# * Most of the customers have income before 70,000

# %% [markdown]
# ### Observations on Miles

# %%
histogram_boxplot(data.Miles)

# %% [markdown]
# **Observations**
# * Miles is positively skewed
# * Majority of the Miles covered is around the ~50 and ~150
# * Median pickups = 94 but the mean is ~103
# * Like Income, and unlike the other variables, this variable has a few more outliers to the right

# %% [markdown]
# ## Let us explore the categorical variables now

# %%
# User defined function to generate barplot of my variables to indicate percentage each category
# This is essential so that I do not have to repeat
# the same block of codes for each variable

## PARAM:
## plot - 
## feature - categorical feature array

def bar_perc(plot, feature):
    # get length of the column
    total = len(feature)
    
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        ax.annotate(percentage, (x, y), size = 12) # annotate the percantage

# %% [markdown]
# ### Observations on Product

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data['Product'])
plt.xlabel('Product')
plt.ylabel('Count')
bar_perc(ax, data['Product'])

# %% [markdown]
# **Observations**
# * 44.4% of the treadmills are TM195, while 33.3% are TM498 and TM798 is 22.2%

# %% [markdown]
# ### Observations on Gender

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data['Gender'])
plt.xlabel('Gender')
plt.ylabel('Count')
bar_perc(ax, data['Gender'])

# %% [markdown]
# **Observations**
# * More than 50% of the customers are Male

# %% [markdown]
# ### Observations on MaritalStatus

# %%
plt.figure(figsize=(15,7))
ax = sns.countplot(data['MaritalStatus'])
plt.xlabel('MaritalStatus')
plt.ylabel('Count')
bar_perc(ax, data['MaritalStatus'])

# %% [markdown]
# **Observations**
# * ~60% of the customers are people who have partners

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Obverving the relation between all variables using Pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ### Observe correction between all variables in a tabular format

# %%
data.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# ### Using heatmap to observe correction above

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations**
#
# * It is ofcourse expected to that there should be high positive correction between Usage, Miles and Fitness

# %%
sns.scatterplot(data["Miles"], data["Income"],  hue=data["Product"], palette="Set2")
# Out:
# <AxesSubplot:xlabel='Miles', ylabel='Income'>

# %% [markdown]
# **Observations**
#
# * It is obvious to see that people with higher Income levels purchase more of TM798 and also cover more Miles
# * While both TM195 and TM498 are concentrated below Income of 70000 and 150 Miles

# %%
sns.scatterplot(data["Education"], data["Income"],  hue=data["Product"], palette="Set1")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Income'>
